# %%
from Test import Test, Resultat, Prediction

# %%
Test(91)
# Out:
# ...
# Essonne
# ...
# #0) Données
# 2011 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2012 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2013 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2014 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2015 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2016 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2017 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2018 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2019 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2020 [7, 8, 9]
# 2021 [5, 6, 7, 8, 9]
# 2022 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 2023 [1, 2, 3, 4, 5, 6, 7, 8, 9]
# le manque de donnes en 2020 et 2021 s'explique par la crise sanitaire de 2020 ainsi nous allons reinstraindre notre analyse sur les periodes avant 2020.
# Pour les mois dont les donnes sont manquantes nous avons interpoler
# ...
# #1) Saisonnalité et Stationnarite
#                             OLS Regression Results
# ...
# Dep. Variable:         OBS_VALUE_CORR   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.847
# ...

# %%
Prediction(91)
# Out:
# === Évaluation hors-échantillon ===
# RMSE : 0.0502
# MAE : 0.0381
# MAPE (%) : 0.3432
# R2 : 0.8032
# {'RMSE': np.float64(0.050186656913680065),
#  'MAE': 0.038103672637264406,
#  'MAPE (%)': np.float64(0.3432052958374031),
#  'R2': 0.8032001628465091}

# %%
resultat = Resultat(10)# resultats pour les dix premier communes
resultat.head(10)
# Out:
#    departement                  nom_dep  \
# 0            1                      Ain
# 1            2                    Aisne
# 2            3                   Allier
# 3            4  Alpes-de-Haute-Provence
# 4            5             Hautes-Alpes
# 5            6          Alpes-Maritimes
# 6            7                  Ardèche
# 7            8                 Ardennes
# 8            9                   Ariège
# 9           10                     Aube
#
#                                           donne_pres  qualite  \
# 0  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 1  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 2  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 3  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 4  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 5  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# 6  {2011: [1, 2, 3, 4, 5, 6, 7, 8, 9], 2012: [1, ...        0
# ...

# %%
resultat.code.describe()
# Out:
# count          10
# unique          2
# top       mauvais
# freq            6
# Name: code, dtype: object
